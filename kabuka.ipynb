# %%
# !pip3 install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (0.2.14)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: requests>=2.26 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: pytz>=2022.5 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2023.3)
# Requirement already satisfied: html5lib>=1.1 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2.3.6)
# Requirement already satisfied: pandas>=1.3.0 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: cryptography>=3.3.2 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (3.4.8)
# Requirement already satisfied: lxml>=4.9.1 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: numpy>=1.16.5 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=3.3.2->yfinance) (1.15.0)
# Requirement already satisfied: webencodings in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: pycparser in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
#
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %matplotlib inline

# %%
aapl = yf.Ticker("AAPL")

# %%
aapl
# Out:
# yfinance.Ticker object <AAPL>

# %%
days = 20
hist = aapl.history(period = f'{days}d')
# Out:
# AAPL: No data found for this date range, symbol may be delisted

# %%
hist.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
hist.reset_index()
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
hist_msft = yf.Ticker('MSFT').history(period = f'{days}d')
hist_msft.head()
# Out:
# MSFT: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
pd.concat([hist,hist_msft],axis = 1).head()
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
hist.head(3)
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
hist.index
# Out:
# Index([], dtype='object', name='Date')

# %%
hist.index = hist.index.strftime('%d %B %Y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 hist.index = hist.index.strftime('%d %B %Y')
#
# AttributeError: 'Index' object has no attribute 'strftime'

# %%
hist.head()
# Out:
#                      Open        High         Low       Close    Volume  \
# Date
# 10 March 2023  150.210007  150.940002  147.610001  148.500000  68524400
# 13 March 2023  147.809998  153.139999  147.699997  150.470001  84457100
# 14 March 2023  151.279999  153.399994  150.100006  152.589996  73695900
# 15 March 2023  151.190002  153.250000  149.919998  152.990005  77167900
# 16 March 2023  152.160004  156.460007  151.639999  155.850006  76161100
#
#                Dividends  Stock Splits
# Date
# 10 March 2023        0.0           0.0
# 13 March 2023        0.0           0.0
# 14 March 2023        0.0           0.0
# 15 March 2023        0.0           0.0
# 16 March 2023        0.0           0.0

# %%
hist = hist [['Close']]
hist.columns = ["apple"]

# %%
hist.head()
# Out:
#                     apple
# Date
# 10 March 2023  148.500000
# 13 March 2023  150.470001
# 14 March 2023  152.589996
# 15 March 2023  152.990005
# 16 March 2023  155.850006

# %%
hist = hist.T
hist
# Out:
# Date   10 March 2023  13 March 2023  14 March 2023  15 March 2023  \
# apple          148.5     150.470001     152.589996     152.990005
#
# Date   16 March 2023  17 March 2023  20 March 2023  21 March 2023  \
# apple     155.850006          155.0     157.399994     159.279999
#
# Date   22 March 2023  23 March 2023  24 March 2023  27 March 2023  \
# apple     157.830002     158.929993         160.25     158.279999
#
# Date   28 March 2023  29 March 2023  30 March 2023  31 March 2023  \
# apple     157.649994     160.770004     162.360001     164.899994
#
# Date   03 April 2023  04 April 2023  05 April 2023  06 April 2023
# apple     166.169998     165.630005     163.759995     164.660004

# %%
hist.index.name = 'Name'

# %%
hist
# Out:
# Date   10 March 2023  13 March 2023  14 March 2023  15 March 2023  \
# Name
# apple          148.5     150.470001     152.589996     152.990005
#
# Date   16 March 2023  17 March 2023  20 March 2023  21 March 2023  \
# Name
# apple     155.850006          155.0     157.399994     159.279999
#
# Date   22 March 2023  23 March 2023  24 March 2023  27 March 2023  \
# Name
# apple     157.830002     158.929993         160.25     158.279999
#
# Date   28 March 2023  29 March 2023  30 March 2023  31 March 2023  \
# Name
# apple     157.649994     160.770004     162.360001     164.899994
#
# Date   03 April 2023  04 April 2023  05 April 2023  06 April 2023
# Name
# apple     166.169998     165.630005     163.759995     164.660004

# %%
days = 20
tickers = {
    'apple': 'AAPL',
    'amazon':'AMZN',
    'google':'GOOGL',
    "microsoft":'MSFT',
    'netflix':'NFLX'
}
def get_data(days,tickers):
    df = pd.DataFrame()
    for company in tickers.keys():
        tkr = yf.Ticker(tickers[company])
        hist = tkr.history(period = f'{days}d')
        hist.index = hist.index.strftime('%d %B %Y')
        hist = hist [['Close']]
        hist.columns = [company]
        hist = hist.T
        hist.index.name = 'Name'
        df = pd.concat([df,hist])
    return df

# %%
days  = 20
get_data(days,tickers)
# Out:
# Date       10 March 2023  13 March 2023  14 March 2023  15 March 2023  \
# Name
# apple         148.500000     150.470001     152.589996     152.990005
# amazon         90.730003      92.430000      94.879997      96.199997
# google         90.629997      91.110001      93.970001      96.110001
# microsoft     248.589996     253.919998     260.790009     265.440002
# netflix       292.760010     293.510010     294.940002     303.790009
#
# Date       16 March 2023  17 March 2023  20 March 2023  21 March 2023  \
# Name
# apple         155.850006     155.000000     157.399994     159.279999
# amazon        100.040001      98.949997      97.709999     100.610001
# google        100.320000     101.620003     101.220001     104.919998
# microsoft     276.200012     279.429993     272.230011     273.779999
# netflix       310.059998     303.500000     305.130005     305.790009
#
# Date       22 March 2023  23 March 2023  24 March 2023  27 March 2023  \
# Name
# apple         157.830002     158.929993     160.250000     158.279999
# amazon         98.699997      98.709999      98.129997      98.040001
# google        103.370003     105.599998     105.440002     102.459999
# microsoft     272.290009     277.660004     280.570007     276.380005
# netflix       293.899994     320.369995     328.390015     327.660004
#
# Date       28 March 2023  29 March 2023  30 March 2023  31 March 2023  \
# Name
# apple         157.649994     160.770004     162.360001     164.899994
# amazon         97.239998     100.250000     102.000000     103.290001
# google        101.029999     101.389999     100.889999     103.730003
# microsoft     275.230011     280.510010     284.049988     288.299988
# netflix       323.519989     332.029999     338.429993     345.480011
#
# Date       03 April 2023  04 April 2023  05 April 2023  06 April 2023
# Name
# apple         166.169998     165.630005     163.759995     164.660004
# amazon        102.410004     103.949997     101.099998     102.059998
# google        104.360001     104.720001     104.470001     108.419998
# microsoft     287.230011     287.179993     284.339996     291.600006
# netflix       348.279999     346.750000     342.350006     339.329987

# %%
# !pip3 install altair
# Out:
# Requirement already satisfied: altair in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (4.2.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from altair) (4.4.0)
# Requirement already satisfied: pandas>=0.18 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from altair) (1.4.2)
# Requirement already satisfied: entrypoints in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from altair) (0.4)
# Requirement already satisfied: jinja2 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from altair) (2.11.3)
# Requirement already satisfied: toolz in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from altair) (0.11.2)
# Requirement already satisfied: numpy in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from altair) (1.21.5)
# Requirement already satisfied: attrs>=17.4.0 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.18->altair) (2023.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from jinja2->altair) (2.0.1)
# Requirement already satisfied: six>=1.5 in /Users/hayata/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)
#
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import altair as alt

# %%
df
# Out:
# Date       10 March 2023  13 March 2023  14 March 2023  15 March 2023  \
# Name
# apple         148.500000     150.470001     152.589996     152.990005
# amazon         90.730003      92.430000      94.879997      96.199997
# google         90.629997      91.110001      93.970001      96.110001
# microsoft     248.589996     253.919998     260.790009     265.440002
# netflix       292.760010     293.510010     294.940002     303.790009
#
# Date       16 March 2023  17 March 2023  20 March 2023  21 March 2023  \
# Name
# apple         155.850006     155.000000     157.399994     159.279999
# amazon        100.040001      98.949997      97.709999     100.610001
# google        100.320000     101.620003     101.220001     104.919998
# microsoft     276.200012     279.429993     272.230011     273.779999
# netflix       310.059998     303.500000     305.130005     305.790009
#
# Date       22 March 2023  23 March 2023  24 March 2023  27 March 2023  \
# Name
# apple         157.830002     158.929993     160.250000     158.279999
# amazon         98.699997      98.709999      98.129997      98.040001
# google        103.370003     105.599998     105.440002     102.459999
# microsoft     272.290009     277.660004     280.570007     276.380005
# netflix       293.899994     320.369995     328.390015     327.660004
#
# Date       28 March 2023  29 March 2023  30 March 2023  31 March 2023  \
# Name
# apple         157.649994     160.770004     162.360001     164.899994
# amazon         97.239998     100.250000     102.000000     103.290001
# google        101.029999     101.389999     100.889999     103.730003
# microsoft     275.230011     280.510010     284.049988     288.299988
# netflix       323.519989     332.029999     338.429993     345.480011
#
# Date       03 April 2023  04 April 2023  05 April 2023  06 April 2023
# Name
# apple         166.169998     165.630005     163.759995     164.660004
# amazon        102.410004     103.949997     101.099998     102.059998
# google        104.360001     104.720001     104.470001     108.419998
# microsoft     287.230011     287.179993     284.339996     291.600006
# netflix       348.279999     346.750000     342.350006     339.329987

# %%
companies = ['apple',"amazon"]
data = df.loc[companies]
data
# Out:
# Date    10 March 2023  13 March 2023  14 March 2023  15 March 2023  \
# Name
# apple      148.500000     150.470001     152.589996     152.990005
# amazon      90.730003      92.430000      94.879997      96.199997
#
# Date    16 March 2023  17 March 2023  20 March 2023  21 March 2023  \
# Name
# apple      155.850006     155.000000     157.399994     159.279999
# amazon     100.040001      98.949997      97.709999     100.610001
#
# Date    22 March 2023  23 March 2023  24 March 2023  27 March 2023  \
# Name
# apple      157.830002     158.929993     160.250000     158.279999
# amazon      98.699997      98.709999      98.129997      98.040001
#
# Date    28 March 2023  29 March 2023  30 March 2023  31 March 2023  \
# Name
# apple      157.649994     160.770004     162.360001     164.899994
# amazon      97.239998     100.250000     102.000000     103.290001
#
# Date    03 April 2023  04 April 2023  05 April 2023  06 April 2023
# Name
# apple      166.169998     165.630005     163.759995     164.660004
# amazon     102.410004     103.949997     101.099998     102.059998

# %%
data.sort_index()
# Out:
# Date    10 March 2023  13 March 2023  14 March 2023  15 March 2023  \
# Name
# amazon      90.730003      92.430000      94.879997      96.199997
# apple      148.500000     150.470001     152.589996     152.990005
#
# Date    16 March 2023  17 March 2023  20 March 2023  21 March 2023  \
# Name
# amazon     100.040001      98.949997      97.709999     100.610001
# apple      155.850006     155.000000     157.399994     159.279999
#
# Date    22 March 2023  23 March 2023  24 March 2023  27 March 2023  \
# Name
# amazon      98.699997      98.709999      98.129997      98.040001
# apple      157.830002     158.929993     160.250000     158.279999
#
# Date    28 March 2023  29 March 2023  30 March 2023  31 March 2023  \
# Name
# amazon      97.239998     100.250000     102.000000     103.290001
# apple      157.649994     160.770004     162.360001     164.899994
#
# Date    03 April 2023  04 April 2023  05 April 2023  06 April 2023
# Name
# amazon     102.410004     103.949997     101.099998     102.059998
# apple      166.169998     165.630005     163.759995     164.660004

# %%
data = data.T.reset_index()

# %%
data.head()
# Out:
# Name           Date       apple      amazon
# 0     10 March 2023  148.500000   90.730003
# 1     13 March 2023  150.470001   92.430000
# 2     14 March 2023  152.589996   94.879997
# 3     15 March 2023  152.990005   96.199997
# 4     16 March 2023  155.850006  100.040001

# %%
data = pd.melt(data,id_vars = ["Date"]).rename(columns = {'value':'Stock Prices(USD)'})
data
# Out:
#              Date    Name  Stock Prices(USD)
# 0   10 March 2023   apple         148.500000
# 1   13 March 2023   apple         150.470001
# 2   14 March 2023   apple         152.589996
# 3   15 March 2023   apple         152.990005
# 4   16 March 2023   apple         155.850006
# 5   17 March 2023   apple         155.000000
# 6   20 March 2023   apple         157.399994
# 7   21 March 2023   apple         159.279999
# 8   22 March 2023   apple         157.830002
# 9   23 March 2023   apple         158.929993
# 10  24 March 2023   apple         160.250000
# 11  27 March 2023   apple         158.279999
# 12  28 March 2023   apple         157.649994
# 13  29 March 2023   apple         160.770004
# 14  30 March 2023   apple         162.360001
# 15  31 March 2023   apple         164.899994
# 16  03 April 2023   apple         166.169998
# 17  04 April 2023   apple         165.630005
# 18  05 April 2023   apple         163.759995
# 19  06 April 2023   apple         164.660004
# 20  10 March 2023  amazon          90.730003
# 21  13 March 2023  amazon          92.430000
# 22  14 March 2023  amazon          94.879997
# 23  15 March 2023  amazon          96.199997
# 24  16 March 2023  amazon         100.040001
# 25  17 March 2023  amazon          98.949997
# 26  20 March 2023  amazon          97.709999
# 27  21 March 2023  amazon         100.610001
# 28  22 March 2023  amazon          98.699997
# 29  23 March 2023  amazon          98.709999
# 30  24 March 2023  amazon          98.129997
# 31  27 March 2023  amazon          98.040001
# 32  28 March 2023  amazon          97.239998
# 33  29 March 2023  amazon         100.250000
# 34  30 March 2023  amazon         102.000000
# 35  31 March 2023  amazon         103.290001
# 36  03 April 2023  amazon         102.410004
# 37  04 April 2023  amazon         103.949997
# 38  05 April 2023  amazon         101.099998
# 39  06 April 2023  amazon         102.059998

# %%
ymin,ymax = 100,300
chart = (
    alt.Chart(data)
    .mark_line(opacity = 0.8,clip = True)
    .encode(
    x = "Date:T",
    y = alt.Y("Stock Prices(USD):Q",stack = None,scale = alt.Scale(domain = [ymin,ymax])),
    color = "Name:N"))

# %%
chart
# Out:
# alt.Chart(...)
